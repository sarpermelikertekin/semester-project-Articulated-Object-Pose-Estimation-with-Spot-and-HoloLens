# %%
import os.path
from xml.dom import minidom


#### ONLY ONE OBJECT PER IMAGE IS ASSUMED ####

out_dir = './out1'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

file = minidom.parse('annotations.xml')

images = file.getElementsByTagName('image')

for image in images:

    width = int(image.getAttribute('width'))
    height = int(image.getAttribute('height'))
    name = image.getAttribute('name')
    elem = image.getElementsByTagName('points')
    bbox = image.getElementsByTagName('box')[0]
    xtl = int(float(bbox.getAttribute('xtl')))
    ytl = int(float(bbox.getAttribute('ytl')))
    xbr = int(float(bbox.getAttribute('xbr')))
    ybr = int(float(bbox.getAttribute('ybr')))
    w = xbr - xtl
    h = ybr - ytl
    label_file = open(os.path.join(out_dir, name[:-4] + '.txt'), 'w')

    for e in elem:

        label_file.write('0 {} {} {} {} '.format(str((xtl + (w / 2)) / width), str((ytl + (h / 2)) / height),
                                                 str(w / width), str(h / height)))

        points = e.attributes['points']
        points = points.value.split(';')
        points_ = []
        for p in points:
            p = p.split(',')
            p1, p2 = p
            points_.append([int(float(p1)), int(float(p2))])
        for p_, p in enumerate(points_):
            label_file.write('{} {}'.format(p[0] / width, p[1] / height))
            if p_ < len(points_) - 1:
                label_file.write(' ')
            else:
                label_file.write('\n')

# %%
import os

def rename_files(directory):
    # Check if the directory exists
    if not os.path.exists(directory):
        print("Directory does not exist.")
        return

    # Iterate over all files in the directory
    for filename in os.listdir(directory):
        # Construct the old file path
        old_file = os.path.join(directory, filename)

        # Skip directories, only rename files
        if os.path.isfile(old_file):
            # Construct the new file path
            new_file = os.path.join(directory, "r" + filename)

            # Rename the file
            os.rename(old_file, new_file)
            print(f"Renamed {filename} to {new_file}")

# Specify the directory
directory_path = r"C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels"
rename_files(directory_path)
# Out:
# Renamed 0.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r0.txt
# Renamed 1.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r1.txt
# Renamed 10.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r10.txt
# Renamed 11.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r11.txt
# Renamed 12.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r12.txt
# Renamed 13.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r13.txt
# Renamed 14.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r14.txt
# Renamed 15.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r15.txt
# Renamed 16.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r16.txt
# Renamed 17.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r17.txt
# Renamed 18.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r18.txt
# Renamed 19.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r19.txt
# Renamed 2.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r2.txt
# Renamed 20.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r20.txt
# Renamed 21.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r21.txt
# Renamed 22.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r22.txt
# Renamed 23.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r23.txt
# Renamed 24.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r24.txt
# Renamed 25.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r25.txt
# Renamed 26.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r26.txt
# Renamed 27.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r27.txt
# Renamed 28.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r28.txt
# Renamed 29.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r29.txt
# Renamed 3.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r3.txt
# Renamed 30.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r30.txt
# Renamed 31.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r31.txt
# Renamed 32.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r32.txt
# Renamed 33.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r33.txt
# Renamed 34.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r34.txt
# Renamed 35.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r35.txt
# Renamed 36.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r36.txt
# Renamed 37.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r37.txt
# Renamed 38.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r38.txt
# Renamed 39.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r39.txt
# Renamed 4.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r4.txt
# Renamed 40.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r40.txt
# Renamed 41.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r41.txt
# Renamed 42.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r42.txt
# Renamed 43.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r43.txt
# Renamed 44.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r44.txt
# Renamed 45.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r45.txt
# Renamed 46.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r46.txt
# Renamed 47.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r47.txt
# Renamed 48.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r48.txt
# Renamed 49.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r49.txt
# Renamed 5.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r5.txt
# Renamed 6.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r6.txt
# Renamed 7.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r7.txt
# Renamed 8.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r8.txt
# Renamed 9.txt to C:\Users\sakar\Semester Project\Spot Datasets\Real Life\labels\r9.txt
